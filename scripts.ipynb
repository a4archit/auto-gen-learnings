# %% [markdown]
# ```text
# messages=[
#
#     TextMessage(
#         id='508cfd18-c0b2-4216-8d39-6847360ae06d',
#         source='user',
#         models_usage=None,
#         metadata={},
#         created_at=datetime.datetime(2025, 12, 21, 2, 39, 42, 258232, tzinfo=datetime.timezone.utc),
#         content='create a newsletter about mobile phones and save the newsletter',
#         type='TextMessage'
#     ),
#
#     ToolCallRequestEvent(
#         id='743e0098-6e0e-493c-b11a-cd54e3b5e77a',
#         source='newsletter_agent',
#         models_usage=RequestUsage(prompt_tokens=273, completion_tokens=17),
#         metadata={},
#         created_at=datetime.datetime(2025, 12, 21, 2, 39, 44, 75358, tzinfo=datetime.timezone.utc),
#         content=[
#
#             FunctionCall(
#                 id='call_Um3JmLR7pzzY4HNLmq8mMtJ3',
#                 arguments='{"topic":"mobile phones"}', name='get_news_headlines'
#             )
#         ],
#         type='ToolCallRequestEvent'
#     ),
#
#     ToolCallExecutionEvent(
#         id='5e55aadf-d532-4516-92ef-9e41b59dfb75',
#         source='newsletter_agent',
#         models_usage=None, metadata={},
#         created_at=datetime.datetime(2025, 12, 21, 2, 39, 45, 698425, tzinfo=datetime.timezone.utc),
#         content=[
#
#             FunctionExecutionResult(
#                 content='[\'# Cell Phones. * All Cell Phones with Plans. * Apple - 240W USB-C Charge Cable (2 m) - White. * Best Buy essentials™ - 20W Dual-Port Wall Charging Kit for USB-C Smartphones, Tablets and More (2 Pack) - White. ## Shop cell phone accessories. * Samsung - Galaxy S25 Ultra 256GB (Unlocked) - Titanium Black. * Apple - iPhone 16 128GB - Apple Intelligence (Unlocked) - Black. * Apple - iPhone 16e 128GB - Apple Intelligence (Unlocked) - Black. * Apple - iPhone 16 Plus 128GB - Apple Intelligence (Unlocked) - Black. * Samsung - Galaxy A16 5G 128GB (Unlocked) - Blue Black. * Unplugged - UP Phone 256GB (Unlocked) - Privacy Gray. ## Shop cell phones by type. ## Shop cell phones by carrier. Trade in your cell phone. Finding the best cell phone for you. choose a prepaid phone and phone plan. if you want a mobile phone with greater customization options and a wide range of models to choose from. using an unlocked phone internationally.\', "### iPhone 17 Pro. ### iPhone 16 Pro. ### Galaxy A36 5G. ### Galaxy A16 5G. ### Galaxy XCover7 Pro 5G. Credit approval, deposit, qualifying service, and, in stores & on customer service calls, $35 assisted support, upgrade support or device connection charge due at sale. Monthly payments on accessories are only allowed for logged in T-Mobile customers or new customers who add a new line to cart. ## Share your screen with an Expert. By clicking \'Accept and continue,\' you are consenting to allow the Expert to view your screen for assisted navigation. **Next:** Generate a code to share with your Expert. ## Share this code with your Expert. Once your code has been successfully entered by your Expert, this window will close and continue to the session. ## Allow screen sharing with your Expert? Ending your session will stop sharing your screen, but will not end your call. Your screen is no longer being shared with your Expert. Generate a new one to share with your Expert.", \'θFor a limited time only, on Samsung.com or Shop Samsung App. When purchasing a new qualifying device (“Qualifying Purchase”), send in your qualifying trade-in device to Samsung through the Samsung Trade-In Program, and if Samsung determines your trade-in device meets all eligibility requirements, you will receive a trade-in credit specific to your qualifying trade-in device to apply toward your Qualifying Purchase. θFor a limited time only, on Samsung.com or Shop Samsung App. When purchasing a new qualifying device (“Qualifying Purchase”), send in your qualifying trade-in device to Samsung through the Samsung Trade-In Program, and if Samsung determines your trade-in device meets all eligibility requirements, you will receive a trade-in credit specific to your qualifying trade-in device to apply toward your Qualifying Purchase. The Trade-In Program cannot be combined with any other Samsung, carrier or retailer promotions, discounts, or offers unless specifically provided for in the terms and conditions of such offers.\']',
#
#                 name='get_news_headlines',
#                 call_id='call_Um3JmLR7pzzY4HNLmq8mMtJ3',
#                 is_error=False
#             )
#         ],
#         type='ToolCallExecutionEvent'
#     ),
#
#     ToolCallRequestEvent(
#         id='5e42bd47-6c8f-4cd7-9fcb-4987c8aba034',
#         source='newsletter_agent',
#         models_usage=RequestUsage(prompt_tokens=942, completion_tokens=290),
#         metadata={},
#         created_at=datetime.datetime(2025, 12, 21, 2, 39, 53, 488343, tzinfo=datetime.timezone.utc),
#         content=[
#
#             FunctionCall(
#                 id='call_RqZJjGkxStVfSolSuY9iSb7J',
#                 arguments='{"news_headlines":"# Mobile Phones Newsletter\\n\\n## Latest Trends & Accessories\\n- **Apple - 240W USB-C Charge Cable (2 m)** - White\\n- **Best Buy essentials™ - 20W Dual-Port Wall Charging Kit for USB-C Smartphones, Tablets and More (2 Pack)** - White\\n\\n## Featured Mobile Phones\\n- **Samsung - Galaxy S25 Ultra 256GB** (Unlocked) - Titanium Black\\n- **Apple - iPhone 16 128GB** (Unlocked) - Black\\n- **Apple - iPhone 16e 128GB** (Unlocked) - Black\\n- **Apple - iPhone 16 Plus 128GB** (Unlocked) - Black\\n- **Samsung - Galaxy A16 5G 128GB** (Unlocked) - Blue Black\\n- **Unplugged - UP Phone 256GB** (Unlocked) - Privacy Gray\\n\\n### New Releases\\n- **iPhone 17 Pro**\\n- **iPhone 16 Pro**\\n- **Galaxy A36 5G**\\n- **Galaxy A16 5G**\\n- **Galaxy XCover7 Pro 5G**\\n\\n## Trade-In Programs\\nTake advantage of trade-in programs when purchasing new devices. Sending in your qualifying trade-in device can earn you credit towards your new purchase."}',
#
#                 name='save_newsletter'
#             )
#         ],
#         type='ToolCallRequestEvent'
#     ),
#
#     ToolCallExecutionEvent(
#         id='24e0c046-0bfa-439f-8d1c-7ee0bd451c00',
#         source='newsletter_agent',
#         models_usage=None,
#         metadata={},
#         created_at=datetime.datetime(2025, 12, 21, 2, 39, 53, 651651, tzinfo=datetime.timezone.utc),
#         content=[
#
#             FunctionExecutionResult(
#                 content='newsletter saved',
#                 name='save_newsletter',
#                 call_id='call_RqZJjGkxStVfSolSuY9iSb7J',
#                 is_error=False
#             )
#         ],
#         type='ToolCallExecutionEvent'
#     ),
#
#     ToolCallSummaryMessage(
#         id='d85f339c-329a-4951-bf23-dca91123bdf7',
#         source='newsletter_agent',
#         models_usage=None,
#         metadata={},
#         created_at=datetime.datetime(2025, 12, 21, 2, 39, 53, 651723, tzinfo=datetime.timezone.utc),
#         content='newsletter saved',
#         type='ToolCallSummaryMessage',
#         tool_calls=[
#
#             FunctionCall(
#                 id='call_RqZJjGkxStVfSolSuY9iSb7J',
#                 arguments='{"news_headlines":"# Mobile Phones Newsletter\\n\\n## Latest Trends & Accessories\\n- **Apple - 240W USB-C Charge Cable (2 m)** - White\\n- **Best Buy essentials™ - 20W Dual-Port Wall Charging Kit for USB-C Smartphones, Tablets and More (2 Pack)** - White\\n\\n## Featured Mobile Phones\\n- **Samsung - Galaxy S25 Ultra 256GB** (Unlocked) - Titanium Black\\n- **Apple - iPhone 16 128GB** (Unlocked) - Black\\n- **Apple - iPhone 16e 128GB** (Unlocked) - Black\\n- **Apple - iPhone 16 Plus 128GB** (Unlocked) - Black\\n- **Samsung - Galaxy A16 5G 128GB** (Unlocked) - Blue Black\\n- **Unplugged - UP Phone 256GB** (Unlocked) - Privacy Gray\\n\\n### New Releases\\n- **iPhone 17 Pro**\\n- **iPhone 16 Pro**\\n- **Galaxy A36 5G**\\n- **Galaxy A16 5G**\\n- **Galaxy XCover7 Pro 5G**\\n\\n## Trade-In Programs\\nTake advantage of trade-in programs when purchasing new devices. Sending in your qualifying trade-in device can earn you credit towards your new purchase."}',
#                 name='save_newsletter'
#             )
#         ],
#
#         results=[
#             FunctionExecutionResult(
#                 content='newsletter saved',
#                 name='save_newsletter',
#                 call_id='call_RqZJjGkxStVfSolSuY9iSb7J',
#                 is_error=False
#             )
#         ]
#     )
# ]
#
# stop_reason=None
# ```

# %% [markdown]
# ```text
# messages=[
#
#     TextMessage(
#         id='508cfd18-c0b2-4216-8d39-6847360ae06d',
#         source='user',
#         models_usage=None,
#         metadata={},
#         created_at=datetime.datetime(2025, 12, 21, 2, 39, 42, 258232, tzinfo=datetime.timezone.utc),
#         content='create a newsletter about mobile phones and save the newsletter',
#         type='TextMessage'
#     ),
#
#     ToolCallRequestEvent(
#         id='743e0098-6e0e-493c-b11a-cd54e3b5e77a',
#         source='newsletter_agent',
#         models_usage=RequestUsage(prompt_tokens=273, completion_tokens=17),
#         metadata={},
#         created_at=datetime.datetime(2025, 12, 21, 2, 39, 44, 75358, tzinfo=datetime.timezone.utc),
#         content=[
#
#             FunctionCall(
#                 id='call_Um3JmLR7pzzY4HNLmq8mMtJ3',
#                 arguments='{"topic":"mobile phones"}', name='get_news_headlines'
#             )
#         ],
#         type='ToolCallRequestEvent'
#     ),
#
#     ToolCallExecutionEvent(
#         id='5e55aadf-d532-4516-92ef-9e41b59dfb75',
#         source='newsletter_agent',
#         models_usage=None, metadata={},
#         created_at=datetime.datetime(2025, 12, 21, 2, 39, 45, 698425, tzinfo=datetime.timezone.utc),
#         content=[
#
#             FunctionExecutionResult(
#                 content='...',
#                 name='get_news_headlines',
#                 call_id='call_Um3JmLR7pzzY4HNLmq8mMtJ3',
#                 is_error=False
#             )
#         ],
#         type='ToolCallExecutionEvent'
#     ),
#
#     ToolCallRequestEvent(
#         id='5e42bd47-6c8f-4cd7-9fcb-4987c8aba034',
#         source='newsletter_agent',
#         models_usage=RequestUsage(prompt_tokens=942, completion_tokens=290),
#         metadata={},
#         created_at=datetime.datetime(2025, 12, 21, 2, 39, 53, 488343, tzinfo=datetime.timezone.utc),
#         content=[
#
#             FunctionCall(
#                 id='call_RqZJjGkxStVfSolSuY9iSb7J',
#                 arguments='{"news_headlines":"---"}',
#                 name='save_newsletter'
#             )
#         ],
#         type='ToolCallRequestEvent'
#     ),
#
#     ToolCallExecutionEvent(
#         id='24e0c046-0bfa-439f-8d1c-7ee0bd451c00',
#         source='newsletter_agent',
#         models_usage=None,
#         metadata={},
#         created_at=datetime.datetime(2025, 12, 21, 2, 39, 53, 651651, tzinfo=datetime.timezone.utc),
#         content=[
#
#             FunctionExecutionResult(
#                 content='newsletter saved',
#                 name='save_newsletter',
#                 call_id='call_RqZJjGkxStVfSolSuY9iSb7J',
#                 is_error=False
#             )
#         ],
#         type='ToolCallExecutionEvent'
#     ),
#
#     ToolCallSummaryMessage(
#         id='d85f339c-329a-4951-bf23-dca91123bdf7',
#         source='newsletter_agent',
#         models_usage=None,
#         metadata={},
#         created_at=datetime.datetime(2025, 12, 21, 2, 39, 53, 651723, tzinfo=datetime.timezone.utc),
#         content='newsletter saved',
#         type='ToolCallSummaryMessage',
#         tool_calls=[
#
#             FunctionCall(
#                 id='call_RqZJjGkxStVfSolSuY9iSb7J',
#                 arguments='{"news_headlines":"---"}',
#                 name='save_newsletter'
#             )
#         ],
#
#         results=[
#             FunctionExecutionResult(
#                 content='newsletter saved',
#                 name='save_newsletter',
#                 call_id='call_RqZJjGkxStVfSolSuY9iSb7J',
#                 is_error=False
#             )
#         ]
#     )
# ]
#
# stop_reason=None
# ```
